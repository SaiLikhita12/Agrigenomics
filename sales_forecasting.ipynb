# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiLikhita12/Agrigenomics/blob/main/sales_forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LINEAR REGRESSION

# %%
import pandas as pd
pd.read_csv("/content/archive.zip")
# Out:
#         TV      Radio  Social Media Influencer       Sales
# 0     16.0   6.566231      2.907983       Mega   54.732757
# 1     13.0   9.237765      2.409567       Mega   46.677897
# 2     41.0  15.886446      2.913410       Mega  150.177829
# 3     83.0  30.020028      6.922304       Mega  298.246340
# 4     15.0   8.437408      1.405998      Micro   56.594181
# ...    ...        ...           ...        ...         ...
# 4567  26.0   4.472360      0.717090      Micro   94.685866
# 4568  71.0  20.610685      6.545573       Nano  249.101915
# 4569  44.0  19.800072      5.096192      Micro  163.631457
# 4570  71.0  17.534640      1.940873      Macro  253.610411
# 4571  42.0  15.966688      5.046548      Micro  148.202414
#
# [4572 rows x 5 columns]

# %%
data=pd.read_csv("/content/archive.zip")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TV            4562 non-null   float64
#  1   Radio         4568 non-null   float64
#  2   Social Media  4566 non-null   float64
#  3   Influencer    4572 non-null   object
#  4   Sales         4566 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 178.7+ KB

# %%
data.isnull().sum()
# Out:
# TV              10
# Radio            4
# Social Media     6
# Influencer       0
# Sales            6
# dtype: int64

# %%
data.head()
# Out:
#      TV      Radio  Social Media Influencer       Sales
# 0  16.0   6.566231      2.907983       Mega   54.732757
# 1  13.0   9.237765      2.409567       Mega   46.677897
# 2  41.0  15.886446      2.913410       Mega  150.177829
# 3  83.0  30.020028      6.922304       Mega  298.246340
# 4  15.0   8.437408      1.405998      Micro   56.594181

# %%
data.tail()
# Out:
#         TV      Radio  Social Media Influencer       Sales
# 4567  26.0   4.472360      0.717090      Micro   94.685866
# 4568  71.0  20.610685      6.545573       Nano  249.101915
# 4569  44.0  19.800072      5.096192      Micro  163.631457
# 4570  71.0  17.534640      1.940873      Macro  253.610411
# 4571  42.0  15.966688      5.046548      Micro  148.202414

# %%
data.drop(['Social Media','Influencer'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2af62848f4eb> in <module>()
# ----> 1 data.drop(['Social Media','Influencer'],axis=1,inplace=True)
#
# NameError: name 'data' is not defined

# %%
data.dropna(inplace=True)
data
# Out:
#         TV      Radio       Sales
# 0     16.0   6.566231   54.732757
# 1     13.0   9.237765   46.677897
# 2     41.0  15.886446  150.177829
# 3     83.0  30.020028  298.246340
# 4     15.0   8.437408   56.594181
# ...    ...        ...         ...
# 4567  26.0   4.472360   94.685866
# 4568  71.0  20.610685  249.101915
# 4569  44.0  19.800072  163.631457
# 4570  71.0  17.534640  253.610411
# 4571  42.0  15.966688  148.202414
#
# [4552 rows x 3 columns]

# %%
data.isnull().sum()
# Out:
# TV       0
# Radio    0
# Sales    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4552 entries, 0 to 4571
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      4552 non-null   float64
#  1   Radio   4552 non-null   float64
#  2   Sales   4552 non-null   float64
# dtypes: float64(3)
# memory usage: 142.2 KB

# %%
import numpy as np
x=data['TV']
y=data['Sales']
x,y
# Out:
# (0       16.0
#  1       13.0
#  2       41.0
#  3       83.0
#  4       15.0
#          ...
#  4567    26.0
#  4568    71.0
#  4569    44.0
#  4570    71.0
#  4571    42.0
#  Name: TV, Length: 4552, dtype: float64, 0        54.732757
#  1        46.677897
#  2       150.177829
#  3       298.246340
#  4        56.594181
#             ...
#  4567     94.685866
#  4568    249.101915
#  4569    163.631457
#  4570    253.610411
#  4571    148.202414
#  Name: Sales, Length: 4552, dtype: float64)

# %%
x.shape
y.shape
# Out:
# (4552,)

# %%
y.shape
# Out:
# (4552,)

# %%
import numpy as np
x=np.array(data['TV']).reshape(-1,1)
x
x.shape
# Out:
# (4552, 1)

# %%
y=np.array(data['Sales']).reshape(-1,1)
y
y.shape
# Out:
# (4552, 1)

# %%
from sklearn.model_selection import train_test_split
X_inp_train,X_test,y_out_train,y_test=train_test_split(x,y,test_size=0.2)
X_inp_train,X_test,y_out_train,y_test
# Out:
# (array([[76.],
#         [40.],
#         [77.],
#         ...,
#         [28.],
#         [25.],
#         [77.]]), array([[ 69.],
#         [ 75.],
#         [ 20.],
#         [ 24.],
#         [ 87.],
#         [ 44.],
#         [ 57.],
#         [ 75.],
#         [ 63.],
#         [ 89.],
#         [ 65.],
#         [ 20.],
#         [ 65.],
#         [ 32.],
#         [ 28.],
#         [ 43.],
#         [ 73.],
#         [ 58.],
#         [ 78.],
#         [ 54.],
#         [ 85.],
#         [ 96.],
#         [ 16.],
#         [ 63.],
#         [ 20.],
#         [ 98.],
#         [ 56.],
#         [ 12.],
#         [ 90.],
#         [ 60.],
#         [ 72.],
#         [ 68.],
#         [ 60.],
#         [ 99.],
#         [ 42.],
#         [ 83.],
#         [ 68.],
#         [ 60.],
#         [ 40.],
#         [ 55.],
#         [ 94.],
#         [ 52.],
#         [ 34.],
#         [ 49.],
#         [ 10.],
#         [ 70.],
#         [ 22.],
#         [ 74.],
#         [ 19.],
# ...

# %%
data.head()
# Out:
#      TV      Radio       Sales
# 0  16.0   6.566231   54.732757
# 1  13.0   9.237765   46.677897
# 2  41.0  15.886446  150.177829
# 3  83.0  30.020028  298.246340
# 4  15.0   8.437408   56.594181

# %%
from sklearn.linear_model import LinearRegression
regr=LinearRegression()
regr
# Out:
# LinearRegression()

# %%
regr.fit(X_inp_train,y_out_train)
# Out:
# LinearRegression()

# %%
print(regr.score(X_test,y_test))
# Out:
# 0.9990662297985727
